# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
classics = pd.read_csv('desktop/classics.csv')
print(classics.shape)
classics.head()
# Out:
# (1006, 34)
#    automated readability index  average letter per word  \
# 0                         10.7                     4.83
# 1                          7.2                     4.41
# 2                          9.3                     4.65
# 3                         12.6                     4.77
# 4                         13.8                     4.56
#
#    average sentence length  average sentence per word  birth  characters  \
# 0                     18.0                       0.05   1775      586794
# 1                     15.0                       0.06   1860       26769
# 2                     17.0                       0.06   1832      122719
# 3                     23.0                       0.04   1797      357604
# 4                     27.0                       0.04   1883      100372
#
#    coleman liau index  dale chall readability score  day  death  ...  \
# 0               10.73                          5.70    1   1817  ...
# ...

# %%
classics.isnull().sum()
# Out:
# automated readability index     0
# average letter per word         0
# average sentence length         0
# average sentence per word       0
# birth                           0
# characters                      0
# coleman liau index              0
# dale chall readability score    0
# day                             0
# death                           0
# difficult words                 0
# downloads                       0
# flesch kincaid grade            0
# flesch reading ease             0
# full                            0
# gunning fog                     0
# id                              0
# linsear write formula           0
# month                           0
# month name                      0
# name                            0
# polarity                        0
# polysyllables                   0
# rank                            0
# sentences                       0
# smog index                      0
# subjectivity                    0
# ...

# %%
# This didn't work

# x = classics['birth']
# y = classics['average sentence length']

# denominator, xedges, yedges = np.histogram2d(x, y, bins=5)
# nominator, _, _ = np.histogram(x, y, bins =[xedges, yedges], weights=.2)

# %%
pd.options.display.max_columns = 500
classics.describe()
# Out:
#        automated readability index  average letter per word  \
# count                  1006.000000              1006.000000
# mean                     12.349602                 4.911352
# std                       5.560579                 0.351216
# min                       4.900000                 4.170000
# 25%                       9.200000                 4.710000
# 50%                      11.400000                 4.865000
# 75%                      14.300000                 5.030000
# max                     125.100000                 9.030000
#
#        average sentence length  average sentence per word        birth  \
# count              1006.000000                1006.000000  1006.000000
# mean                 20.801193                   0.054135  1414.925447
# std                  10.740644                   0.020521   773.309251
# min                   5.000000                   0.000000  -750.000000
# ...

# %%
# Looking at just the modern-ish books

classics1700 = classics[classics['birth'] > 1700]

# %%
print(classics1700.shape)
classics1700.head()
# Out:
# (701, 34)
#    automated readability index  average letter per word  \
# 0                         10.7                     4.83
# 1                          7.2                     4.41
# 2                          9.3                     4.65
# 3                         12.6                     4.77
# 4                         13.8                     4.56
#
#    average sentence length  average sentence per word  birth  characters  \
# 0                     18.0                       0.05   1775      586794
# 1                     15.0                       0.06   1860       26769
# 2                     17.0                       0.06   1832      122719
# 3                     23.0                       0.04   1797      357604
# 4                     27.0                       0.04   1883      100372
#
#    coleman liau index  dale chall readability score  day  death  ...  \
# 0               10.73                          5.70    1   1817  ...
# ...

# %%
classics1700.describe()
# Out:
#        automated readability index  average letter per word  \
# count                   701.000000               701.000000
# mean                     11.766904                 4.914936
# std                       5.618354                 0.352986
# min                       4.900000                 4.170000
# 25%                       9.000000                 4.710000
# 50%                      10.900000                 4.870000
# 75%                      13.700000                 5.040000
# max                     125.100000                 9.030000
#
#        average sentence length  average sentence per word        birth  \
# count               701.000000                 701.000000   701.000000
# mean                 19.603424                   0.056262  1842.891583
# std                  10.490523                   0.020333    46.511009
# min                   5.000000                   0.000000  1703.000000
# ...

# %%
# Looking around at specific entries

longest = classics[classics['average sentence length'] == 57.0]
longest
# Out:
#      automated readability index  average letter per word  \
# 510                         30.0                     4.78
#
#      average sentence length  average sentence per word  birth  characters  \
# 510                     57.0                       0.02   -384      488832
#
#      coleman liau index  dale chall readability score  day  death  ...  \
# 510               11.33                          7.52    1   -322  ...
#
#      sentences  smog index  subjectivity  syllables  \
# 510       1768        11.2      0.492125   148254.3
#
#                                   title  total  type  \
# 510  Politics: A Treatise on Government      6  Text
#
#                                        url   words  year
# 510  https://www.gutenberg.org/ebooks/6762  102328  2004
#
# [1 rows x 34 columns]

# %%
classics['words'].median()
# Out:
# 65020.5

# %%
# Mentioned this specific book in my blog post

classics[classics['title'] == 'Ulysses']
# Out:
#     automated readability index  average letter per word  \
# 13                          8.6                     4.95
#
#     average sentence length  average sentence per word  birth  characters  \
# 13                     13.0                       0.07   1882     1311231
#
#     coleman liau index  dale chall readability score  day  death  ...  \
# 13               10.84                          6.35    1   1941  ...
#
#     sentences  smog index  subjectivity  syllables    title  total  type  \
# 13      19726         3.1      0.463067   363292.2  Ulysses      7  Text
#
#                                       url   words  year
# 13  https://www.gutenberg.org/ebooks/4300  264835  2003
#
# [1 rows x 34 columns]

# %%
! pip install plotly
# Out:
# ...
#     100% |████████████████████████████████| 41.2MB 748kB/s eta 0:00:01
# ...
#   Stored in directory: /Users/mattmastin/Library/Caches/pip/wheels/d7/a9/33/acc7b709e2a35caa7d4cae442f6fe6fbf2c43f80823d46460c
# Successfully built retrying
# ...

# %%
! pip install cufflinks
# Out:
# ...
#     100% |████████████████████████████████| 81kB 1.4MB/s ta 0:00:01
# ...
#   Stored in directory: /Users/mattmastin/Library/Caches/pip/wheels/c7/7f/d3/7d3146a1551614bf0b8eb631ac724d044dd341679e763b594b
# Successfully built cufflinks
# ...

# %%
import plotly.plotly as py
import plotly.graph_objs as go
from plotly.offline import iplot, init_notebook_mode
import plotly.figure_factory as ff

# %%
import cufflinks as cf
cufflinks.go_offline(connected=True)
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
# ...

# %%
classics['words'].iplot(kind='hist', xTitle='Total Words',
                       yTitle='# of Books', title='Words per Book for the 1,000 Most Popular Project Gutenberg Books')
# Out:
# <div>
#
#
#             <div id="5c98794f-8b6c-4a49-90fa-f5ded3507c31" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("5c98794f-8b6c-4a49-90fa-f5ded3507c31")) {
#                     Plotly.newPlot(
#                         '5c98794f-8b6c-4a49-90fa-f5ded3507c31',
# ...

# %%
# Referenced some of these very long books in blog post

classicslong = classics[classics['words'] > 750000.0]
classicslong
# Out:
#      automated readability index  average letter per word  \
# 55                           7.9                     4.74
# 61                          13.6                     4.49
# 264                         14.5                     6.87
# 279                         17.0                     4.82
# 322                         10.0                     5.61
# 497                         10.0                     4.39
# 784                         11.3                     4.79
# 844                         15.2                     6.27
# 904                          6.2                     4.83
#
#      average sentence length  average sentence per word  birth  characters  \
# 55                      14.0                       0.07   1564     4183870
# 61                      27.0                       0.04      0     3684178
# 264                      7.0                       0.14   1846    12051675
# 279                     31.0                       0.03   1672     4618241
# ...

# %%
# Reran this to make a change, but having trouble with plotly credentials

classics['average sentence length'].iplot(kind='hist', xTitle='Words per Sentence',
                       yTitle='Count', title='Gutenberg Project Average Sentence Length')
# Out:
# Aw, snap! We didn't get a username with your request.
#
# Don't have an account? https://plot.ly/api_signup
#
# Questions? accounts@plot.ly
# ---------------------------------------------------------------------------
# PlotlyError                               Traceback (most recent call last)
# <ipython-input-37-8e57274aeadd> in <module>
#       1 classics['average sentence length'].iplot(kind='hist', xTitle='Words per Sentence',
# ----> 2                        yTitle='# of Books', title='Gutenberg Project Average Sentence Length')
#
# ...

# %%
# Didn't work for me

# trace = go.Scatter(
#             x = classics['birth'],
#             y = classics['average letter per word'], mode='markers')

# data = [trace]

# py.iplot(data, filename='basic-scatter')

# %%
corrs = classics.corr()

# %%
figure = ff.create_annotated_heatmap(z=corrs.values, 
                                    x=list(corrs.columns), y=list(corrs.index),
                                    annotation_text=corrs.round(2).values,
                                    showscale=True);

# %%
classics.iplot(kind='scatter', x='average sentence length', y='average letter per word',
               xTitle='Average Sentence Length',
               yTitle='Average Word Length', 
               title='No One Wants to Read Long Sentences with Long Words', 
               mode='markers')
# Out:
# <div>
#
#
#             <div id="40bda9c8-998f-4d9a-bc6c-a16da3015e72" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("40bda9c8-998f-4d9a-bc6c-a16da3015e72")) {
#                     Plotly.newPlot(
#                         '40bda9c8-998f-4d9a-bc6c-a16da3015e72',
# ...

# %%
longsentence = classics[classics['average sentence length'] > 50]
longsentence
# Out:
#      automated readability index  average letter per word  \
# 60                          27.9                     4.72
# 96                          27.8                     4.61
# 132                         26.5                     4.68
# 210                         40.7                     4.74
# 342                         28.2                     4.92
# 471                         29.9                     4.85
# 504                         30.9                     4.80
# 510                         30.0                     4.78
# 544                        125.1                     6.08
# 693                         30.9                     5.08
# 835                         26.1                     4.61
#
#      average sentence length  average sentence per word  birth  characters  \
# 60                      54.0                       0.02   1632      266846
# 96                      55.0                       0.02   1478      200527
# ...

# %%
longwords = classics[classics['average letter per word'] > 6]
longwords
# Out:
#      automated readability index  average letter per word  \
# 145                         11.4                     6.05
# 148                         12.5                     6.29
# 256                         13.7                     6.08
# 264                         14.5                     6.87
# 268                         18.5                     6.07
# 282                         16.1                     7.13
# 407                         19.9                     6.14
# 544                        125.1                     6.08
# 624                         23.8                     9.03
# 629                         15.6                     6.10
# 637                         14.7                     6.55
# 667                         17.2                     6.07
# 684                         15.6                     6.15
# 820                         14.5                     6.75
# 844                         15.2                     6.27
# ...

# %%
# Proof of concept matplotlib before making the much better looking plotly version of above

plt.scatter(classics1700['average sentence length'], classics1700['average letter per word'])

# %%
# Using another related dataset

publishers = pd.read_csv('desktop/publishers.csv')
print(publishers.shape)
publishers.head()
# Out:
# (27027, 13)
#    amazon revenue  author revenue  average rating          genre  gross sales  \
# 0          6832.0          6832.0            4.57  genre fiction      34160.0
# 1          2487.5          2487.5            4.47  genre fiction      12437.5
# 2          9559.0          9559.0            4.16  genre fiction      47795.0
# 3          8250.0          8250.0            3.84        fiction      41250.0
# 4          7590.5          7590.5            4.75  genre fiction      37952.5
#
#                           name  publisher revenue  sale price  sales rank  \
# 0        Katherine Tegen Books            20496.0        4.88           1
# 1        HarperCollins e-books             7462.5        1.99           2
# 2  (Small or Medium Publisher)            28677.0        8.69           3
# 3    Little, Brown and Company            24750.0        7.50           3
# 4            Dutton Children's            22771.5        7.99           4
#
# ...

# %%
publishers.isnull().sum()
# Out:
# amazon revenue       0
# author revenue       0
# average rating       0
# genre                0
# gross sales          0
# name                 0
# publisher revenue    0
# sale price           0
# sales rank           0
# sold by              0
# total reviews        0
# type                 0
# units sold           0
# dtype: int64

# %%
# trace = go.Scatter(x = publishers['average rating'], y = publishers['gross sales'])
# data = [trace]
# py.iplot(data)

publishers.iplot(x='average rating', y='gross sales', categories='genre', 
                xTitle='Average Rating', yTitle='Gross Sales ($)',
                title='Amazon e-book Sales Are Dependent on High Ratings')
# Out:
# <div>
#
#
#             <div id="97a94aae-ecb3-43c7-973d-411e8dbeac98" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("97a94aae-ecb3-43c7-973d-411e8dbeac98")) {
#                     Plotly.newPlot(
#                         '97a94aae-ecb3-43c7-973d-411e8dbeac98',
# ...

# %%
publishers.describe()
# Out:
#        amazon revenue  author revenue  average rating   gross sales  \
# count    27027.000000    27027.000000    27027.000000  27027.000000
# mean        37.978937       41.465654        4.159787    150.572864
# std        250.995881      223.321357        0.995815    865.653698
# min          0.004000        0.004000        0.000000      0.020000
# 25%          3.992000        4.036000        4.080000     16.000000
# 50%          9.576000       10.152000        4.400000     41.860000
# 75%         21.978000       25.116000        4.640000     98.910000
# max      12974.000000     9559.000000        5.000000  47795.000000
#
#        publisher revenue    sale price    sales rank  total reviews  \
# count       27027.000000  27027.000000  27027.000000   27027.000000
# mean           71.128273      6.777488  38200.142857     136.099345
# std           481.337817      6.368486  29056.493296     468.952999
# min             0.000000      0.010000      1.000000       0.000000
# ...

# %%
publishers.corr()
# Out:
#                    amazon revenue  author revenue  average rating  \
# amazon revenue           1.000000        0.895943       -0.000276
# author revenue           0.895943        1.000000        0.007282
# average rating          -0.000276        0.007282        1.000000
# gross sales              0.871855        0.910713       -0.004102
# publisher revenue        0.630836        0.706703       -0.010611
# sale price               0.012056        0.008096        0.000607
# sales rank              -0.157378       -0.191079       -0.058274
# total reviews            0.287296        0.321027        0.044760
# units sold               0.822220        0.848408        0.011845
#
#                    gross sales  publisher revenue  sale price  sales rank  \
# amazon revenue        0.871855           0.630836    0.012056   -0.157378
# author revenue        0.910713           0.706703    0.008096   -0.191079
# average rating       -0.004102          -0.010611    0.000607   -0.058274
# ...

# %%
publishers4star = publishers[publishers['average rating'] < 4.0]
publishers4star['gross sales'].sum()
# Out:
# 715463.69

# %%
publishers3star = publishers[publishers['average rating'] < 3.0]
publishers3star['gross sales'].sum()
# Out:
# 228659.66999999995

# %%
publishers4star.describe()
# Out:
#        amazon revenue  author revenue  average rating   gross sales  \
# count     5255.000000     5255.000000     5255.000000   5255.000000
# mean        32.825201       33.232525        2.764261    136.149132
# std        225.856162      189.682791        1.543960    874.373698
# min          0.004000        0.004000        0.000000      0.020000
# 25%          2.990000        2.990000        2.440000     11.960000
# 50%          7.800000        7.992000        3.580000     32.890000
# 75%         18.863000       21.978000        3.830000     83.040000
# max      10379.200000     8250.000000        3.990000  41250.000000
#
#        publisher revenue   sale price    sales rank  total reviews  \
# count        5255.000000  5255.000000   5255.000000    5255.000000
# mean           70.091406     6.552339  41213.509420     114.248145
# std           506.490980     8.520493  29772.192662     543.850046
# min             0.000000     0.010000      3.000000       0.000000
# ...

# %%
publishers['gross sales'].sum()
# Out:
# 4069532.7899999996

# %%
publishers4star['gross sales'].sum() / publishers['gross sales'].sum()
# Out:
# 0.1758097862629582

# %%
publishers3star['gross sales'].sum() / publishers['gross sales'].sum()
# Out:
# 0.056188187145679684

# %%
# Dumb factoid to liven up blog

sentence = 'On the surface it seems likely that ostentatiously loquacious writers would be equally prone to flights of fancy with their word choice, but it seems the main goal of being properly comprehended precludes the use of maximizing both word and sentence length'
words = sentence.split()
average = sum(len(word) for word in words) / len(words)
average
# Out:
# 5.119047619047619

# %%
classics1700.iplot(kind='scatter', x='birth', y='difficult words',
               xTitle='Author Birth Year',
               yTitle='# Difficult Words', 
               title='20th Century Decline of Difficult Words or an Evolving Language?', 
               mode='markers')
# Out:
# <div>
#
#
#             <div id="a6ee43ca-6bf6-452a-b772-032a4fa1e217" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("a6ee43ca-6bf6-452a-b772-032a4fa1e217")) {
#                     Plotly.newPlot(
#                         'a6ee43ca-6bf6-452a-b772-032a4fa1e217',
# ...

# %%
classics1900 = classics[classics['birth'] > 1899]
print(classics1900.shape)
classics1900.head(60)
# Out:
# (60, 34)
#       automated readability index  average letter per word  \
# 139                           7.3                     5.01
# 164                           9.5                     5.16
# 170                           6.4                     4.67
# 191                           6.5                     4.29
# 203                           7.1                     4.88
# 233                           7.5                     4.75
# 237                           9.7                     5.16
# 251                           6.0                     5.02
# 252                           7.9                     4.97
# 260                           6.6                     4.94
# 276                           9.1                     5.01
# 281                           7.4                     4.83
# 313                           8.2                     4.97
# 327                           9.6                     5.15
# 357                           8.0                     4.91
# ...

# %%
classics1900.describe()
# Out:
#        automated readability index  average letter per word  \
# count                     60.00000                60.000000
# mean                       7.96500                 4.935500
# std                        1.59924                 0.190026
# min                        5.30000                 4.290000
# 25%                        6.67500                 4.857500
# 50%                        7.95000                 4.935000
# 75%                        8.92500                 5.047500
# max                       13.00000                 5.320000
#
#        average sentence length  average sentence per word        birth  \
# count                60.000000                  60.000000    60.000000
# mean                 11.766667                   0.085333  1922.683333
# std                   2.794466                   0.019784     8.583571
# min                   7.000000                   0.050000  1905.000000
# ...

# %%
classics1800 = classics[classics['birth'] > 1799]

# %%
classics1800 = classics1800[classics1800['birth'] < 1900]
print(classics1800.shape)
classics1800.describe()
# Out:
# (550, 34)
#        automated readability index  average letter per word  \
# count                   550.000000               550.000000
# mean                     11.640727                 4.905000
# std                       5.820172                 0.334413
# min                       4.900000                 4.170000
# 25%                       9.125000                 4.690000
# 50%                      10.800000                 4.850000
# 75%                      13.300000                 5.040000
# max                     125.100000                 6.870000
#
#        average sentence length  average sentence per word        birth  \
# count               550.000000                 550.000000   550.000000
# mean                 19.452727                   0.055291  1848.647273
# std                  10.758000                   0.017002    24.710033
# min                   7.000000                   0.000000  1800.000000
# ...

# %%
classicshard = classics1700[classics1700['difficult words'] > 30000]
classicshard
# Out:
#       automated readability index  average letter per word  \
# 13                            8.6                     4.95
# 24                           10.2                     4.93
# 148                          12.5                     6.29
# 264                          14.5                     6.87
# 356                          14.7                     5.81
# 497                          10.0                     4.39
# 713                          12.6                     5.07
# 718                          13.3                     5.44
# 784                          11.3                     4.79
# 838                          12.2                     5.19
# 878                          14.4                     5.36
# 1004                         12.3                     5.31
#
#       average sentence length  average sentence per word  birth  characters  \
# 13                       13.0                       0.07   1882     1311231
# ...
